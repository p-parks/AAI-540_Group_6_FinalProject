# %%
import pandas as pd

# %%
df = pd.read_csv("CEAS_08_cleaned.csv")
df
# Out:
#                                                   sender  \
# 0                       Young Esposito <Young@iworld.de>
# 1                           Mok <ipline's1983@icable.ph>
# 2      Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                     Michael Parker <ivqrnai@pobox.com>
# 4      Gretchen Suggs <externalsep1@loanofficertool.com>
# ...                                                  ...
# 39149    CNN Alerts <charlene-detecton@btcmarketing.com>
# 39150           CNN Alerts <idgetily1971@careplusnj.org>
# 39151                   Abhijit Vyas <xpojhbz@gmail.com>
# 39152              Joseph Brennan <vupzesm@columbia.edu>
# 39153                Christian Heimes <wluhe@cheimes.de>
#
#                                                  subject  \
# 0                              Never agree to be a loser
# 1                                 Befriend Jenna Jameson
# 2                                   CNN.com Daily Top 10
# ...

# %%
# Create a new DataFrame for HAM emails
ham_df = df[df['label'] == 0]

# Create a new DataFrame for SPAM emails
spam_df = df[df['label'] == 1]

# Save the HAM DataFrame as a new CSV file
ham_df.to_csv('ham.csv', index=False)

# Save the SPAM DataFrame as a new CSV file
spam_df.to_csv('spam.csv', index=False)

# %%
ham_df
# Out:
#                                       sender  \
# 3         Michael Parker <ivqrnai@pobox.com>
# 8          qydlqcws-iacfym@issues.apache.org
# 15                Racing <uqyrmo@sailing.ie>
# 18       Aaron Kulkis <cmiqlkx91@hotpop.com>
# 19       Aaron Kulkis <cmiqlkx91@hotpop.com>
# ...                                      ...
# 39138     robert healy <vrcjauctt@gmail.com>
# 39147  Nick Zeljkovic <kppyozizjt@site5.com>
# 39151       Abhijit Vyas <xpojhbz@gmail.com>
# 39152  Joseph Brennan <vupzesm@columbia.edu>
# 39153    Christian Heimes <wluhe@cheimes.de>
#
#                                                  subject  \
# 3      Re: svn commit: r619753 - in /spamassassin/tru...
# 8      [Bug 5780] URI processing turns uuencoded stri...
# 15                 RE: Trial IRC Certificate Application
# 18     Re: [opensuse] Why can't I use "shutdown now" ...
# 19       Re: Fwd: [opensuse] Re: openSUSE Boxed Editions
# ...                                                  ...
# ...

# %%
spam_df
# Out:
#                                                   sender  \
# 0                       Young Esposito <Young@iworld.de>
# 1                           Mok <ipline's1983@icable.ph>
# 2      Daily Top 10 <Karmandeep-opengevl@universalnet...
# 4      Gretchen Suggs <externalsep1@loanofficertool.com>
# 5      Caroline Aragon <dwthaidomainnamesm@thaidomain...
# ...                                                  ...
# 39145             Amandalee <tamekut_1991@smarttech.com>
# 39146        CNN Alerts <tidhamsu_2002@tyler.sprnet.org>
# 39148                 Amee Zeisler <dlintentions@ctk.cz>
# 39149    CNN Alerts <charlene-detecton@btcmarketing.com>
# 39150           CNN Alerts <idgetily1971@careplusnj.org>
#
#                                                  subject  \
# 0                              Never agree to be a loser
# 1                                 Befriend Jenna Jameson
# 2                                   CNN.com Daily Top 10
# ...
